# %%
import tabula
import pandas as pd

# %%
# We have already downloded the pdf
# Now, convert the table on page no 54 into a csv file using tabula.

# Note: Keep our pdf in current directory.

tabula.convert_into('Walmart.pdf', 'Walmart.csv', pages=56)

# %%
# Open and view the table in Pandas Dataframe

df = pd.read_csv('Walmart.csv')
df
# Out:
#          (Amounts in millions, except per share data) Unnamed: 1     2023  \
# 0                                           Revenues:        NaN      NaN
# 1                                           Net sales          $  605,881
# 2                         Membership and other income        NaN    5,408
# 3                                      Total revenues        NaN  611,289
# 4                                 Costs and expenses:        NaN      NaN
# 5                                       Cost of sales        NaN  463,721
# 6   Operating, selling, general and administrative...        NaN  127,140
# 7                                    Operating income        NaN   20,428
# 8                                           Interest:        NaN      NaN
# 9                                                Debt        NaN    1,787
# 10                                      Finance lease        NaN      341
# 11                                    Interest income        NaN    (254)
# 12                                      Interest, net        NaN    1,874
# 13                     Loss on extinguishment of debt        NaN        —
# 14                           Other (gains) and losses        NaN    1,538
# 15                         Income before income taxes        NaN   17,016
# 16                         Provision for income taxes        NaN    5,724
# 17                            Consolidated net income        NaN   11,292
# 18  Consolidated net (income) loss attributable to...        NaN      388
# 19    Consolidated net income attributable to Walmart          $   11,680
# 20                       Net income per common share:        NaN      NaN
# 21  Basic net income per common share attributable...          $     4.29
# 22  Diluted net income per common share attributab...        NaN     4.27
# 23        Weighted-average common shares outstanding:        NaN      NaN
# 24                                              Basic        NaN    2,724
# 25                                            Diluted        NaN    2,734
# 26                Dividends declared per common share          $     2.24
#
#    Unnamed: 3     2022 Unnamed: 5     2021
# 0         NaN      NaN        NaN      NaN
# 1           $  567,762          $  555,233
# 2         NaN    4,992        NaN    3,918
# 3         NaN  572,754        NaN  559,151
# 4         NaN      NaN        NaN      NaN
# 5         NaN  429,000        NaN  420,315
# 6         NaN  117,812        NaN  116,288
# 7         NaN   25,942        NaN   22,548
# 8         NaN      NaN        NaN      NaN
# 9         NaN    1,674        NaN    1,976
# 10        NaN      320        NaN      339
# 11        NaN    (158)        NaN    (121)
# 12        NaN    1,836        NaN    2,194
# 13        NaN    2,410        NaN        —
# 14        NaN    3,000        NaN    (210)
# 15        NaN   18,696        NaN   20,564
# 16        NaN    4,756        NaN    6,858
# 17        NaN   13,940        NaN   13,706
# 18        NaN    (267)        NaN    (196)
# 19          $   13,673          $   13,510
# 20        NaN      NaN        NaN      NaN
# 21          $     4.90          $     4.77
# 22        NaN     4.87        NaN     4.75
# 23        NaN      NaN        NaN      NaN
# 24        NaN    2,792        NaN    2,831
# 25        NaN    2,805        NaN    2,847
# 26          $     2.20          $     2.16

# %%
# Check all comumns

df.columns
# Out:
# Index(['(Amounts in millions, except per share data)', 'Unnamed: 1', '2023',
#        'Unnamed: 3', '2022', 'Unnamed: 5', '2021'],
#       dtype='object')

# %%
# Delete unnecessary columns

del df['Unnamed: 1']
del df['Unnamed: 3']
del df['Unnamed: 5']

df
# Out:
#          (Amounts in millions, except per share data)     2023     2022  \
# 0                                           Revenues:      NaN      NaN
# 1                                           Net sales  605,881  567,762
# 2                         Membership and other income    5,408    4,992
# 3                                      Total revenues  611,289  572,754
# 4                                 Costs and expenses:      NaN      NaN
# 5                                       Cost of sales  463,721  429,000
# 6   Operating, selling, general and administrative...  127,140  117,812
# 7                                    Operating income   20,428   25,942
# 8                                           Interest:      NaN      NaN
# 9                                                Debt    1,787    1,674
# 10                                      Finance lease      341      320
# 11                                    Interest income    (254)    (158)
# 12                                      Interest, net    1,874    1,836
# 13                     Loss on extinguishment of debt        —    2,410
# 14                           Other (gains) and losses    1,538    3,000
# 15                         Income before income taxes   17,016   18,696
# 16                         Provision for income taxes    5,724    4,756
# 17                            Consolidated net income   11,292   13,940
# 18  Consolidated net (income) loss attributable to...      388    (267)
# 19    Consolidated net income attributable to Walmart   11,680   13,673
# 20                       Net income per common share:      NaN      NaN
# 21  Basic net income per common share attributable...     4.29     4.90
# 22  Diluted net income per common share attributab...     4.27     4.87
# 23        Weighted-average common shares outstanding:      NaN      NaN
# 24                                              Basic    2,724    2,792
# 25                                            Diluted    2,734    2,805
# 26                Dividends declared per common share     2.24     2.20
#
#        2021
# 0       NaN
# 1   555,233
# 2     3,918
# 3   559,151
# 4       NaN
# 5   420,315
# 6   116,288
# 7    22,548
# 8       NaN
# 9     1,976
# 10      339
# 11    (121)
# 12    2,194
# 13        —
# 14    (210)
# 15   20,564
# 16    6,858
# 17   13,706
# 18    (196)
# 19   13,510
# 20      NaN
# 21     4.77
# 22     4.75
# 23      NaN
# 24    2,831
# 25    2,847
# 26     2.16

# %%
# Rename th first column and replace all the '-' with 0 for further calculations. 

df = df.rename(columns={'(Amounts in millions, except per share data)':'Title'})
df = df.replace(df.iloc[13][1], 0)

# %%
# Replace NaN with 0 to make further calculations easy.

df.fillna(0, inplace=True)
df
# Out:
#                                                 Title     2023     2022  \
# 0                                           Revenues:        0        0
# 1                                           Net sales  605,881  567,762
# 2                         Membership and other income    5,408    4,992
# 3                                      Total revenues  611,289  572,754
# 4                                 Costs and expenses:        0        0
# 5                                       Cost of sales  463,721  429,000
# 6   Operating, selling, general and administrative...  127,140  117,812
# 7                                    Operating income   20,428   25,942
# 8                                           Interest:        0        0
# 9                                                Debt    1,787    1,674
# 10                                      Finance lease      341      320
# 11                                    Interest income    (254)    (158)
# 12                                      Interest, net    1,874    1,836
# 13                     Loss on extinguishment of debt        0    2,410
# 14                           Other (gains) and losses    1,538    3,000
# 15                         Income before income taxes   17,016   18,696
# 16                         Provision for income taxes    5,724    4,756
# 17                            Consolidated net income   11,292   13,940
# 18  Consolidated net (income) loss attributable to...      388    (267)
# 19    Consolidated net income attributable to Walmart   11,680   13,673
# 20                       Net income per common share:        0        0
# 21  Basic net income per common share attributable...     4.29     4.90
# 22  Diluted net income per common share attributab...     4.27     4.87
# 23        Weighted-average common shares outstanding:        0        0
# 24                                              Basic    2,724    2,792
# 25                                            Diluted    2,734    2,805
# 26                Dividends declared per common share     2.24     2.20
#
#        2021
# 0         0
# 1   555,233
# 2     3,918
# 3   559,151
# 4         0
# 5   420,315
# 6   116,288
# 7    22,548
# 8         0
# 9     1,976
# 10      339
# 11    (121)
# 12    2,194
# 13        0
# 14    (210)
# 15   20,564
# 16    6,858
# 17   13,706
# 18    (196)
# 19   13,510
# 20        0
# 21     4.77
# 22     4.75
# 23        0
# 24    2,831
# 25    2,847
# 26     2.16

# %%
# Use ReGex to remove ',','(' and ')' symbols from all columns.

# Convert all columns data type from object to float to make further analysis easy.

df['2021'] = df['2021'].replace(',', '', regex=True)
df['2021'] = df['2021'].replace('\(', '', regex=True)
df['2021'] = df['2021'].replace('\)', '', regex=True)
df['2021'] = df['2021'].astype(float)

df['2022'] = df['2022'].replace(',', '', regex=True)
df['2022'] = df['2022'].replace('\(', '', regex=True)
df['2022'] = df['2022'].replace('\)', '', regex=True)
df['2022'] = df['2022'].astype(float)

df['2023'] = df['2023'].replace(',', '', regex=True)
df['2023'] = df['2023'].replace('\(', '', regex=True)
df['2023'] = df['2023'].replace('\)', '', regex=True)
df['2023'] = df['2023'].astype(float)

# Take a final view
df
# Out:
#                                                 Title       2023       2022  \
# 0                                           Revenues:       0.00       0.00
# 1                                           Net sales  605881.00  567762.00
# 2                         Membership and other income    5408.00    4992.00
# 3                                      Total revenues  611289.00  572754.00
# 4                                 Costs and expenses:       0.00       0.00
# 5                                       Cost of sales  463721.00  429000.00
# 6   Operating, selling, general and administrative...  127140.00  117812.00
# 7                                    Operating income   20428.00   25942.00
# 8                                           Interest:       0.00       0.00
# 9                                                Debt    1787.00    1674.00
# 10                                      Finance lease     341.00     320.00
# 11                                    Interest income     254.00     158.00
# 12                                      Interest, net    1874.00    1836.00
# 13                     Loss on extinguishment of debt       0.00    2410.00
# 14                           Other (gains) and losses    1538.00    3000.00
# 15                         Income before income taxes   17016.00   18696.00
# 16                         Provision for income taxes    5724.00    4756.00
# 17                            Consolidated net income   11292.00   13940.00
# 18  Consolidated net (income) loss attributable to...     388.00     267.00
# 19    Consolidated net income attributable to Walmart   11680.00   13673.00
# 20                       Net income per common share:       0.00       0.00
# 21  Basic net income per common share attributable...       4.29       4.90
# 22  Diluted net income per common share attributab...       4.27       4.87
# 23        Weighted-average common shares outstanding:       0.00       0.00
# 24                                              Basic    2724.00    2792.00
# 25                                            Diluted    2734.00    2805.00
# 26                Dividends declared per common share       2.24       2.20
#
#          2021
# 0        0.00
# 1   555233.00
# 2     3918.00
# 3   559151.00
# 4        0.00
# 5   420315.00
# 6   116288.00
# 7    22548.00
# 8        0.00
# 9     1976.00
# 10     339.00
# 11     121.00
# 12    2194.00
# 13       0.00
# 14     210.00
# 15   20564.00
# 16    6858.00
# 17   13706.00
# 18     196.00
# 19   13510.00
# 20       0.00
# 21       4.77
# 22       4.75
# 23       0.00
# 24    2831.00
# 25    2847.00
# 26       2.16

# %%
# Check all columns data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Title   27 non-null     object
#  1   2023    27 non-null     float64
#  2   2022    27 non-null     float64
#  3   2021    27 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 992.0+ bytes

# %%
# Make sure that NaN values are completely removed. 

df.isnull().sum()
# Out:
# Title    0
# 2023     0
# 2022     0
# 2021     0
# dtype: int64

# %%
# Save this dataframe as csv file to local system.

df.to_csv('Walmart_54.csv')

# %%
# Save this dataframe as pdf to local system

import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.axis('off')
table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center', colWidths=[0.7,0.1,0.1,0.1])
table.auto_set_font_size(False)
table.set_fontsize(7)
plt.savefig('Walmart_54.pdf', format='pdf')

# %% [markdown]
# ### This csv file is now ready for further analysis.
